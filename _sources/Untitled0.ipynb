# %%
import requests as req
from bs4 import BeautifulSoup as bs
from datetime import datetime
import csv

def scraping_berita(halaman):
    a = 1
    with open('berita_suara_sport.csv', 'w', newline='', encoding='utf-8') as file:
        fieldnames = ['Judul_Artikel', 'Content_Artikel', 'Category']
        writer = csv.DictWriter(file, fieldnames=fieldnames)
        writer.writeheader()

        for page in range(1, halaman + 1):
            url = f'https://www.suara.com/indeks/terkini/sport/2023?page={page}'
            html = req.get(url).text
            soup = bs(html, 'lxml')
            list_berita = soup.find('div', class_='list-item-y-img-retangle')
            berita_list = list_berita.find_all('div', class_='item')
            category = 'Sports'

            for berita in berita_list:
                link = berita.find('div', class_='text-list-item-y').find('a')['href']
                headline = berita.find('div', class_='text-list-item-y').find('a').text

                ge_berita = req.get(link).text
                sop_berita = bs(ge_berita, 'lxml')
                content_elem = sop_berita.find_all('article', class_='detail-content detail-berita')
                content_list = [p.text for elem in content_elem for p in elem.find_all('p')]
                artikel = '\n'.join(content_list).replace('ADVERTISEMENT', '').replace('SCROLL TO RESUME CONTENT', '').replace('\n', ' ').strip()

                print(f'data berhasil diambil[{a}] > {headline[0:10]}')
                a += 1

                writer.writerow({'Judul_Artikel': headline, 'Content_Artikel': artikel, 'Category': category})

# pemanggilan fungsi dengan jumlah halaman yang di scraping
scraping_berita(2)
# Out:
# data berhasil diambil[1] >
#
# data berhasil diambil[2] >
#
# data berhasil diambil[3] >
#
# data berhasil diambil[4] >
#
# data berhasil diambil[5] >
#
# data berhasil diambil[6] >
#
# data berhasil diambil[7] >
#
# data berhasil diambil[8] >
#
# data berhasil diambil[9] >
#
# data berhasil diambil[10] >
#
# data berhasil diambil[11] >
#
# data berhasil diambil[12] >
#
# data berhasil diambil[13] >
#
# data berhasil diambil[14] >
#
# data berhasil diambil[15] >
#
# data berhasil diambil[16] >
#
# data berhasil diambil[17] >
#
# data berhasil diambil[18] >
#
# data berhasil diambil[19] >
#
# data berhasil diambil[20] >
#
# data berhasil diambil[21] >
#
# data berhasil diambil[22] >
#
# data berhasil diambil[23] >
#
# data berhasil diambil[24] >
#
# data berhasil diambil[25] >
#
# data berhasil diambil[26] >
#
# data berhasil diambil[27] >
#
# data berhasil diambil[28] >
#
# data berhasil diambil[29] >
#
# data berhasil diambil[30] >
#
# data berhasil diambil[31] >
#
# data berhasil diambil[32] >
#
# data berhasil diambil[33] >
#
# data berhasil diambil[34] >
#
# data berhasil diambil[35] >
#
# data berhasil diambil[36] >
#
# data berhasil diambil[37] >
#
# data berhasil diambil[38] >
#
# data berhasil diambil[39] >
#
# data berhasil diambil[40] >

# %%
import pandas as pd
data = pd.read_csv('berita_suara_sport.csv')
data
# Out:
#                                         Judul_Artikel  \
# 0   \n                        Siap Bertarung di Ch...
# 1   \n                        Berhasil Perlebar Ja...
# 2   \n                        Melempem di Kumamoto...
# 3   \n                        MotoGP Qatar 2023: F...
# 4   \n                        Juara Indonesian Mas...
# 5   \n                        Torehan Prestasi Gre...
# 6   \n                        Hasil F1 GP Las Vega...
# 7   \n                        Jeka Saragih Ukir Se...
# 8   \n                        Gregoria Mariska Tun...
# 9   \n                        PB Djarum Juara Umum...
# 10  \n                        Red Sparks Dibungkam...
# 11  \n                        Singkirkan Zhang Bei...
# 12  \n                        Kumamoto Masters 202...
# 13  \n                        Jelang MotoGP Qatar,...
# 14  \n                        Gregoria Mariska Tun...
# 15  \n                        Kevin / Rahmat Petik...
# 16  \n                        Misi Akhiri Paceklik...
# 17  \n                        Japan Masters 2023: ...
# 18  \n                        Japan Masters 2023, ...
# 19  \n                        Kumamoto Masters 202...
# 20  \n                        Gregoria Beberkan Re...
# 21  \n                        Anthony Ginting Eval...
# 22  \n                        Melenggang ke 16 Bes...
# 23  \n                        Kumamoto Masters 202...
# 24  \n                        Cedera, Putri Kusuma...
# 25  \n                        Megawati Kalah Pamor...
# 26  \n                        Kumamoto Masters 202...
# 27  \n                        Marc Marquez Maksima...
# 28  \n                        Kumamoto Masters 202...
# 29  \n                        Pram/Yere Tekuk Waki...
# 30  \n                        Bagas/Fikri Ingin Pe...
# 31  \n                        Shesar Hiren Rhustav...
# 32  \n                        Makin Kompak, Kevin/...
# 33  \n                        Jadwal Japan Masters...
# 34  \n                        Indonesia Gelar Olah...
# 35  \n                        Peselancar Indonesia...
# 36  \n                        Novak Djokovic Pasti...
# 37  \n                        Kumamoto Japan Maste...
# 38  \n                        5 MVP Bold Battle of...
# 39  \n                        Atlet Panjat Tebing ...
#
#                                       Content_Artikel Category
# 0   Suara.com - Skuad Timnas Bulu Tangkis Indonesi...   Sports
# 1   Suara.com - Pembalap Ducati Lenovo Francesco B...   Sports
# 2   Suara.com - Asisten pelatih ganda putra Indone...   Sports
# 3   Suara.com - Pembalap Gresini Racing, Fabio Di ...   Sports
# 4   Suara.com - Pegolf asal India, Gaganjeet Bhull...   Sports
# 5   Suara.com - Sukses tunggal putri Indonesia Gre...   Sports
# 6   Suara.com - Pembalap Red Bull Max Verstappen m...   Sports
# 7   Suara.com - Atlet bela diri campuran Jeka Sara...   Sports
# 8   Suara.com - Tunggal putri Indonesia Gregoria M...   Sports
# 9   Suara.com - Klub asal Kudus, PB Djarum, sukses...   Sports
# 10  Suara.com - Jung Kwan Jang Red Sparks kembali ...   Sports
# 11  Suara.com - Pebulu tangkis tunggal putri Indon...   Sports
# 12  Suara.com - Langkah pebulutangkis tunggal putr...   Sports
# 13  Suara.com - Pembalap Prima Pramac Jorge Martin...   Sports
# 14  Suara.com - Tunggal putri Indonesia Gregoria M...   Sports
# 15  Suara.com - Pasangan ganda putra Indonesia, Ke...   Sports
# 16  Suara.com - Pelita Jaya Bakrie Jakarta resmi "...   Sports
# 17  Suara.com - Pebulu tangkis tunggal putra Indon...   Sports
# 18  Suara.com - Pebulu tangkis tunggal putri Indon...   Sports
# 19  Suara.com - Ganda campuran Indonesia Rinov Riv...   Sports
# 20  Suara.com - Atlet tunggal putri Indonesia, Gre...   Sports
# 21  Suara.com - Pebulutangkis tunggal putra Indone...   Sports
# 22  Suara.com - Pasangan ganda putra Indonesia, Ke...   Sports
# 23  Suara.com - Pebulutangkis tunggal putra Indone...   Sports
# 24  Suara.com - Tunggal putri Indonesia Putri Kusu...   Sports
# 25  Suara.com - Megawati Hangesti Pertiwi terpaksa...   Sports
# 26  Suara.com - Ganda campuran Indonesia Rehan Nau...   Sports
# 27  Suara.com - Pembalap Repsol Honda Marc Marquez...   Sports
# 28  Suara.com - Ganda campuran Indonesia Rinov Riv...   Sports
# 29  Suara.com - Ganda putra Indonesia Pramudya Kus...   Sports
# 30  Suara.com - Pasangan ganda putra Indonesia Bag...   Sports
# 31  Suara.com - Pebulu tangkis tunggal putra Indon...   Sports
# 32  Suara.com - Ganda putra Indonesia Kevin Sanjay...   Sports
# 33  Suara.com - Berikut jadwal Japan Masters 2023 ...   Sports
# 34  Suara.com - Kompetisi olahraga air berskala in...   Sports
# 35  Suara.com - Peselancar Indonesia Febriansyah m...   Sports
# 36  Suara.com - Novak Djokovic memastikan menutup ...   Sports
# 37  Suara.com - Para pebulutangkis Indonesia siap ...   Sports
# 38  Suara.com - Rangkaian turnamen esports Bold Ba...   Sports
# 39  Suara.com - Atlet panjat tebing putra Indonesi...   Sports

# %%
from nltk.tokenize import sent_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import networkx as nx
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import pandas as pd
import numpy as np
import nltk
import re
import joblib

nltk.download('stopwords')
nltk.download('punkt')
warnings.filterwarnings('ignore')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# Inisialisasi TfidfVectorizer
def graph_cosine_sim(x, threshold = 0.11):
  # TFIDF
  vectorizer = TfidfVectorizer()
  tfidf = vectorizer.fit_transform(x)
  cos_sim = cosine_similarity(tfidf)
  G = nx.Graph()

  # Mengisi nilai similarity antara kalimat ke dalam edges (Garis Penghubung)
  for i in range(len(x)):
    for j in range(i+1, len(x)):
      sim = cos_sim[i][j]
      if sim > threshold:
        G.add_edge(i, j, weight=sim)

  return G
